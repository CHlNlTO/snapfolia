# %% [markdown]
# Run this after getting the data in Roboflow
#
# this is used to change the id at the txt file
#
# parts[0] = '1'  # Change this to its proper class id

# %%
import os

# Path to your folder containing text files
folder_path = 'C:\\Users\\faith\\Downloads\\Snapfolia-4-Class.v10i.yolov8\\train\\labels'

for filename in os.listdir(folder_path):

    if filename.endswith('.txt'):
        file_path = os.path.join(folder_path, filename)


        with open(file_path, 'r') as file:
            lines = file.readlines()

        new_lines = []
        for line in lines:
            parts = line.split()
            if len(parts) > 0:
                parts[0] = '39'  # Change this to its proper class id
            new_lines.append(' '.join(parts) + '\n')


        with open(file_path, 'w') as file:
            file.writelines(new_lines)

print("Class ID update completed.")
# Out:
# Class ID update completed.
