# %% [markdown]
# ## Dataset Balancer
# #### - Removes excess data ( para magpantay yung classes)
# #### - If val data > 100 run this code
# #### - If train data > 350 run this code

# %%
import os
import random

def cleanup_excess_images(base_path, target_count):
    """
    Randomly delete images and labels for classes that exceed the target count.
    
    Args:
    - base_path: Path to the dataset directory containing the validation dataset (default is 'dsds/val').
    - target_count: Maximum number of images allowed per class.
    """
    # Iterate through each class directory
    class_dirs = [d for d in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, d))]

    for class_dir in class_dirs:
        class_path = os.path.join(base_path, class_dir)
        images_dir = os.path.join(class_path, 'images')
        labels_dir = os.path.join(class_path, 'labels')
        
        if not os.path.exists(images_dir) or not os.path.exists(labels_dir):
            print(f"Skipping {class_dir}: 'images' or 'labels' directory not found.")
            continue
        
        # Get list of all images
        all_images = [f for f in os.listdir(images_dir) if f.endswith(('.jpg', '.jpeg', '.png', '.gif'))]
        current_count = len(all_images)
        
        print(f"\nProcessing {class_dir}:")
        print(f"Current image count: {current_count}")
        
        if current_count > target_count:
            num_to_delete = current_count - target_count
            print(f"Need to delete {num_to_delete} images.")
            
            # Prefer deleting augmented images first (identified by patterns like '(z' in filename)
            augmented_images = [img for img in all_images if '(z' in img]
            deletion_candidates = augmented_images if augmented_images else all_images
            
            # Randomly select images to delete
            images_to_delete = random.sample(deletion_candidates, num_to_delete)
            
            # Delete selected images and their corresponding labels
            for image_to_delete in images_to_delete:
                # Remove image
                image_path = os.path.join(images_dir, image_to_delete)
                os.remove(image_path)
                
                # Remove corresponding label
                label_name = os.path.splitext(image_to_delete)[0] + '.txt'
                label_path = os.path.join(labels_dir, label_name)
                if os.path.exists(label_path):
                    os.remove(label_path)
            
            # Verify final count
            remaining_images = len([f for f in os.listdir(images_dir) if f.endswith(('.jpg', '.jpeg', '.png', '.gif'))])
            print(f"Images after cleanup: {remaining_images}")
        else:
            print(f"No deletion required for {class_dir}.")

# Call the function
cleanup_excess_images(base_path='F:\SNAPFOLIA\CLS_DS_48 - Copy', target_count=375)
# Out:
# Skipping Acacia: 'images' or 'labels' directory not found.
# Skipping Aherns Balok: 'images' or 'labels' directory not found.
# Skipping Alagao: 'images' or 'labels' directory not found.
# Skipping Alibangbang: 'images' or 'labels' directory not found.
# Skipping Amugis: 'images' or 'labels' directory not found.
# Skipping Antipolo: 'images' or 'labels' directory not found.
# Skipping Apitong: 'images' or 'labels' directory not found.
# Skipping Asis: 'images' or 'labels' directory not found.
# Skipping Balayong: 'images' or 'labels' directory not found.
# Skipping Balete: 'images' or 'labels' directory not found.
# Skipping Banaba: 'images' or 'labels' directory not found.
# Skipping Bani: 'images' or 'labels' directory not found.
# Skipping Banuyo: 'images' or 'labels' directory not found.
# Skipping Barako: 'images' or 'labels' directory not found.
# Skipping Bayabas: 'images' or 'labels' directory not found.
# Skipping Betis: 'images' or 'labels' directory not found.
# Skipping Binunga: 'images' or 'labels' directory not found.
# Skipping Dao: 'images' or 'labels' directory not found.
# Skipping Dita: 'images' or 'labels' directory not found.
# Skipping Duhat: 'images' or 'labels' directory not found.
# Skipping Eucalyptus: 'images' or 'labels' directory not found.
# Skipping Guyabano: 'images' or 'labels' directory not found.
# Skipping Hinadyong: 'images' or 'labels' directory not found.
# Skipping Ilang-Ilang: 'images' or 'labels' directory not found.
# Skipping Inyam: 'images' or 'labels' directory not found.
# Skipping Ipil: 'images' or 'labels' directory not found.
# Skipping Kalantas: 'images' or 'labels' directory not found.
# Skipping Kalios: 'images' or 'labels' directory not found.
# Skipping Kamagong: 'images' or 'labels' directory not found.
# Skipping Langka: 'images' or 'labels' directory not found.
# Skipping Lansones: 'images' or 'labels' directory not found.
# Skipping Lipote: 'images' or 'labels' directory not found.
# Skipping Madre-Cacao: 'images' or 'labels' directory not found.
# Skipping Mahogany: 'images' or 'labels' directory not found.
# Skipping Malak Malak: 'images' or 'labels' directory not found.
# Skipping Mangga: 'images' or 'labels' directory not found.
# Skipping Mulawin: 'images' or 'labels' directory not found.
# Skipping Narra: 'images' or 'labels' directory not found.
# Skipping Palawan Ipil: 'images' or 'labels' directory not found.
# Skipping Palo-Maria: 'images' or 'labels' directory not found.
# Skipping Philippine Oak Ulayan: 'images' or 'labels' directory not found.
# Skipping Santol: 'images' or 'labels' directory not found.
# Skipping Scramble-Egg: 'images' or 'labels' directory not found.
# Skipping Sintores: 'images' or 'labels' directory not found.
# Skipping Talisay: 'images' or 'labels' directory not found.
# Skipping Tibig: 'images' or 'labels' directory not found.
# Skipping White Lawaan: 'images' or 'labels' directory not found.
# Skipping Yakal: 'images' or 'labels' directory not found.

# %%
import random

def cleanup_excess_images(base_path='F:/ds-final-ben/train', target_count=350):
    """
    Randomly delete images and labels for classes that exceed the target count.
    
    Args:
    - base_path: Path to the dataset directory containing the validation dataset (default is 'dsds/val').
    - target_count: Maximum number of images allowed per class.
    """
    # Iterate through each class directory
    class_dirs = [d for d in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, d))]

    for class_dir in class_dirs:
        class_path = os.path.join(base_path, class_dir)
        images_dir = os.path.join(class_path, 'images')
        labels_dir = os.path.join(class_path, 'labels')
        
        if not os.path.exists(images_dir) or not os.path.exists(labels_dir):
            print(f"Skipping {class_dir}: 'images' or 'labels' directory not found.")
            continue
        
        # Get list of all images
        all_images = [f for f in os.listdir(images_dir) if f.endswith(('.jpg', '.jpeg', '.png', '.gif'))]
        current_count = len(all_images)
        
        print(f"\nProcessing {class_dir}:")
        print(f"Current image count: {current_count}")
        
        if current_count > target_count:
            num_to_delete = current_count - target_count
            print(f"Need to delete {num_to_delete} images.")
            
            # Prefer deleting augmented images first (identified by patterns like '(z' in filename)
            augmented_images = [img for img in all_images if '(z' in img]
            deletion_candidates = augmented_images if augmented_images else all_images
            
            # Randomly select images to delete
            images_to_delete = random.sample(deletion_candidates, num_to_delete)
            
            # Delete selected images and their corresponding labels
            for image_to_delete in images_to_delete:
                # Remove image
                image_path = os.path.join(images_dir, image_to_delete)
                os.remove(image_path)
                
                # Remove corresponding label
                label_name = os.path.splitext(image_to_delete)[0] + '.txt'
                label_path = os.path.join(labels_dir, label_name)
                if os.path.exists(label_path):
                    os.remove(label_path)
            
            # Verify final count
            remaining_images = len([f for f in os.listdir(images_dir) if f.endswith(('.jpg', '.jpeg', '.png', '.gif'))])
            print(f"Images after cleanup: {remaining_images}")
        else:
            print(f"No deletion required for {class_dir}.")

# Call the function
cleanup_excess_images(base_path='F:/ds-final-ben/train', target_count=350)

# %% [markdown]
# ## Data Count After Cleanup

# %%
import os
import matplotlib.pyplot as plt

# Path to your training dataset
train_dir = "F:/ds-final-ben/val"

# Count images per class
class_counts = {}

for class_name in os.listdir(train_dir):
    class_path = os.path.join(train_dir, class_name, "images")
    if os.path.isdir(class_path):
        class_counts[class_name] = len([f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))])

# Sort the counts for better visualization
class_counts = dict(sorted(class_counts.items(), key=lambda x: x[0]))

# Plot the chart
plt.figure(figsize=(12, 6))
plt.bar(class_counts.keys(), class_counts.values(), color="skyblue")
plt.xlabel("Class", fontsize=12)
plt.ylabel("Number of Images", fontsize=12)
plt.title("Validation Dataset", fontsize=14)
plt.xticks(rotation=45, ha="right", fontsize=10)
plt.tight_layout()
plt.show()

# %%
import os
import matplotlib.pyplot as plt

# Path to your training dataset
train_dir = "F:/ds-final-ben/train"

# Count images per class
class_counts = {}

for class_name in os.listdir(train_dir):
    class_path = os.path.join(train_dir, class_name, "images")
    if os.path.isdir(class_path):
        class_counts[class_name] = len([f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))])

# Sort the counts for better visualization
class_counts = dict(sorted(class_counts.items(), key=lambda x: x[0]))

# Plot the chart
plt.figure(figsize=(12, 6))
plt.bar(class_counts.keys(), class_counts.values(), color="skyblue")
plt.xlabel("Class", fontsize=12)
plt.ylabel("Number of Images", fontsize=12)
plt.title("Training Dataset", fontsize=14)
plt.xticks(rotation=45, ha="right", fontsize=10)
plt.tight_layout()
plt.show()
