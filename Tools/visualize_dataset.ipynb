# %% [markdown]
# #### Initialize Directories

# %%
DATASET = r"F:\SNAPFOLIA\SNAPFOLIA_DS"

# %%
import os
def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

walk_through_dir(DATASET)
# Out:
# There are 48 directories and 0 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS'.
# There are 0 directories and 320 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Acacia'.
# There are 0 directories and 609 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Aherns Balok'.
# There are 0 directories and 335 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Alagao'.
# There are 0 directories and 437 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Alibangbang'.
# There are 0 directories and 365 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Amugis'.
# There are 0 directories and 361 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Antipolo'.
# There are 0 directories and 296 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Apitong'.
# There are 0 directories and 424 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Asis'.
# There are 0 directories and 222 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Balayong'.
# There are 0 directories and 360 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Balete'.
# There are 0 directories and 314 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Banaba'.
# There are 0 directories and 318 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Bani'.
# There are 0 directories and 529 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Banuyo'.
# There are 0 directories and 262 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Barako'.
# There are 0 directories and 442 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Bayabas'.
# There are 0 directories and 211 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Betis'.
# There are 0 directories and 240 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Binunga'.
# There are 0 directories and 246 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Dao'.
# There are 0 directories and 449 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Dita'.
# There are 0 directories and 406 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Duhat'.
# There are 0 directories and 363 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Eucalyptus'.
# There are 0 directories and 260 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Guyabano'.
# There are 0 directories and 353 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Hinadyong'.
# There are 0 directories and 415 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Ilang-Ilang'.
# There are 0 directories and 355 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Inyam'.
# There are 0 directories and 276 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Ipil'.
# There are 0 directories and 547 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Kalantas'.
# There are 0 directories and 202 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Kalios'.
# There are 0 directories and 229 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Kamagong'.
# There are 0 directories and 446 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Langka'.
# There are 0 directories and 241 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Lansones'.
# There are 0 directories and 495 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Lipote'.
# There are 0 directories and 307 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Madre-Cacao'.
# There are 0 directories and 440 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Mahogany'.
# There are 0 directories and 615 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Malak Malak'.
# There are 0 directories and 439 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Mangga'.
# There are 0 directories and 195 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Mulawin'.
# There are 0 directories and 431 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Narra'.
# There are 0 directories and 537 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Palawan Ipil'.
# There are 0 directories and 371 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Palo-Maria'.
# There are 0 directories and 577 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Philippine Oak Ulayan'.
# There are 0 directories and 367 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Santol'.
# There are 0 directories and 378 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Scramble-Egg'.
# There are 0 directories and 284 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Sintores'.
# There are 0 directories and 297 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Talisay'.
# There are 0 directories and 270 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Tibig'.
# There are 0 directories and 407 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\White Lawaan'.
# There are 0 directories and 164 images in 'F:\SNAPFOLIA\SNAPFOLIA_DS\Yakal'.

# %%
import matplotlib.pyplot as plt

def count_images_in_directories(base_path):
    directory_counts = {}
    for dirpath, dirnames, filenames in os.walk(base_path):
        if dirpath == base_path:
            # Skip the root directory
            continue
        directory_name = os.path.basename(dirpath)
        image_count = len(filenames)
        directory_counts[directory_name] = image_count
    return directory_counts

image_counts = count_images_in_directories(DATASET)
print(image_counts)
# Out:
# {'Acacia': 320, 'Aherns Balok': 609, 'Alagao': 335, 'Alibangbang': 437, 'Amugis': 365, 'Antipolo': 361, 'Apitong': 296, 'Asis': 424, 'Balayong': 222, 'Balete': 360, 'Banaba': 314, 'Bani': 318, 'Banuyo': 529, 'Barako': 262, 'Bayabas': 442, 'Betis': 211, 'Binunga': 240, 'Dao': 246, 'Dita': 449, 'Duhat': 406, 'Eucalyptus': 363, 'Guyabano': 260, 'Hinadyong': 353, 'Ilang-Ilang': 415, 'Inyam': 355, 'Ipil': 276, 'Kalantas': 547, 'Kalios': 202, 'Kamagong': 229, 'Langka': 446, 'Lansones': 241, 'Lipote': 495, 'Madre-Cacao': 307, 'Mahogany': 440, 'Malak Malak': 615, 'Mangga': 439, 'Mulawin': 195, 'Narra': 431, 'Palawan Ipil': 537, 'Palo-Maria': 371, 'Philippine Oak Ulayan': 577, 'Santol': 367, 'Scramble-Egg': 378, 'Sintores': 284, 'Talisay': 297, 'Tibig': 270, 'White Lawaan': 407, 'Yakal': 164}

# %%
def plot_image_counts(base_path, output_file="image_counts.png"):
    # Count images in directories
    image_counts = count_images_in_directories(base_path)
    
    # Sort data for better visualization
    sorted_counts = dict(sorted(image_counts.items(), key=lambda item: item[1], reverse=True))
    
    
    # Extract data for the chart
    directories = list(sorted_counts.keys())
    counts = list(sorted_counts.values())
    
    # Plot horizontal bar chart
    plt.figure(figsize=(10, len(directories) * 0.4))  # Adjust height based on the number of directories
    plt.barh(directories, counts, color='skyblue')
    
    # Add labels and title
    plt.xlabel('Number of Classes')
    plt.ylabel('Classes')
    plt.title(f'Number of Classes {len(image_counts)}')
    
    # Display values on bars
    for index, value in enumerate(counts):
        plt.text(value, index, str(value), va='center')
    
    # Save the plot as PNG
    plt.tight_layout()
    plt.savefig(output_file, format="png", dpi=300)
    plt.close()  # Close the plot to free up memory
    
output_path = "images/class_count.png"  
plot_image_counts(DATASET, output_path)
print(f"Plot saved as '{output_path}'")
# Out:
# Plot saved as 'images/class_count.png'
