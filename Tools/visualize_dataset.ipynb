# %% [markdown]
# #### Initialize Directories

# %%
DATASET = r"F:\SNAP-DS-36"
DATASET_4 = r"F:\SNAP-DS-4"

# %%
import os
def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

walk_through_dir(DATASET)
# Out:
# There are 36 directories and 0 images in 'F:\SNAP-DS-36'.
# There are 0 directories and 546 images in 'F:\SNAP-DS-36\Acacia'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Alibangbang'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Amugis'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Apitong'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Asis'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Balayong'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Balete'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Banaba'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Bani'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Barako'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Bayabas'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Betis'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Binunga'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Dao'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Dita'.
# There are 0 directories and 440 images in 'F:\SNAP-DS-36\Duhat'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Eucalyptus'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Guyabano'.
# There are 0 directories and 447 images in 'F:\SNAP-DS-36\Hinadyong'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Ilang Ilang'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Ipil'.
# There are 0 directories and 447 images in 'F:\SNAP-DS-36\Kalios'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Kamagong'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Langka'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Lansones'.
# There are 0 directories and 423 images in 'F:\SNAP-DS-36\Madre Cacao'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Mahogany'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Mangga'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Mulawin'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Narra'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Native Talisay'.
# There are 0 directories and 432 images in 'F:\SNAP-DS-36\Palo Maria'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Scramble Egg'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Sintores'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Tibig'.
# There are 0 directories and 450 images in 'F:\SNAP-DS-36\Yakal'.

# %%
import matplotlib.pyplot as plt

def count_images_in_directories(base_path):
    directory_counts = {}
    for dirpath, dirnames, filenames in os.walk(base_path):
        if dirpath == base_path:
            # Skip the root directory
            continue
        directory_name = os.path.basename(dirpath)
        image_count = len(filenames)
        directory_counts[directory_name] = image_count
    return directory_counts

image_counts = count_images_in_directories(DATASET)
print(image_counts)
# Out:
# {'Acacia': 546, 'Alibangbang': 450, 'Amugis': 450, 'Apitong': 450, 'Asis': 450, 'Balayong': 450, 'Balete': 450, 'Banaba': 450, 'Bani': 450, 'Barako': 450, 'Bayabas': 450, 'Betis': 450, 'Binunga': 450, 'Dao': 450, 'Dita': 450, 'Duhat': 440, 'Eucalyptus': 450, 'Guyabano': 450, 'Hinadyong': 447, 'Ilang Ilang': 450, 'Ipil': 450, 'Kalios': 447, 'Kamagong': 450, 'Langka': 450, 'Lansones': 450, 'Madre Cacao': 423, 'Mahogany': 450, 'Mangga': 450, 'Mulawin': 450, 'Narra': 450, 'Native Talisay': 450, 'Palo Maria': 432, 'Scramble Egg': 450, 'Sintores': 450, 'Tibig': 450, 'Yakal': 450}

# %%
def plot_image_counts(base_path, output_file="image_counts.png"):
    # Count images in directories
    image_counts = count_images_in_directories(base_path)
    
    # Sort data for better visualization
    sorted_counts = dict(sorted(image_counts.items(), key=lambda item: item[1], reverse=True))
    
    
    # Extract data for the chart
    directories = list(sorted_counts.keys())
    counts = list(sorted_counts.values())
    
    # Plot horizontal bar chart
    plt.figure(figsize=(10, len(directories) * 0.4))  # Adjust height based on the number of directories
    plt.barh(directories, counts, color='skyblue')
    
    # Add labels and title
    plt.xlabel('Number of Classes')
    plt.ylabel('Classes')
    plt.title(f'Number of Classes {len(image_counts)}')
    
    # Display values on bars
    for index, value in enumerate(counts):
        plt.text(value, index, str(value), va='center')
    
    # Save the plot as PNG
    plt.tight_layout()
    plt.savefig(output_file, format="png", dpi=300)
    plt.close()  # Close the plot to free up memory
    
output_path = "images/class_count.png"  
plot_image_counts(DATASET, output_path)
print(f"Plot saved as '{output_path}'")
# Out:
# Plot saved as 'images/class_count.png'
