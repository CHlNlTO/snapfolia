# %% [markdown]
# #### Initialize Directories

# %%
DATASET = r"F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train"

# %%
import os
def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

walk_through_dir(DATASET)
# Out:
# There are 59 directories and 0 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Acacia'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Aherns Balok'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Alagao'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Alibangbang'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Amugis'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Antipolo'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Apitong'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Asis'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Balayong'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Balete'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Balongeta'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Banaba'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Bani'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Banuyo'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Barako'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Bayabas'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Betis'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Binunga'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Dao'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Dita'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Duhat'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Eucalyptus'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Guyabano'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Hinadyong'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Ilang-Ilang'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Inyam'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Ipil'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Kalantas'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Kalingag'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Kalios'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Kamagong'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Katmon Bayani'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Kayumanis'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Kulatingan'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Langka'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Lansones'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Lipote'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Madre-Cacao'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Mahogany'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Malabulak'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Malak Malak'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Malugai'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Mangga'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Mulawin'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Narra'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Palawan Ipil'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Palo-Maria'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Philippine Oak Ulayan'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Puso Puso'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Putat'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Red Lawaan'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Santol'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Scramble-Egg'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Sintores'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Talisay'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Tibig'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Tui'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\White Lawaan'.
# There are 0 directories and 1050 images in 'F:\SNAPFOLIA\CLS_DS_59 - SPLIT\train\Yakal'.

# %%
import matplotlib.pyplot as plt

def count_images_in_directories(base_path):
    directory_counts = {}
    for dirpath, dirnames, filenames in os.walk(base_path):
        if dirpath == base_path:
            # Skip the root directory
            continue
        directory_name = os.path.basename(dirpath)
        image_count = len(filenames)
        directory_counts[directory_name] = image_count
    return directory_counts

image_counts = count_images_in_directories(DATASET)
print(image_counts)
# Out:
# {'Acacia': 1050, 'Aherns Balok': 1050, 'Alagao': 1050, 'Alibangbang': 1050, 'Amugis': 1050, 'Antipolo': 1050, 'Apitong': 1050, 'Asis': 1050, 'Balayong': 1050, 'Balete': 1050, 'Balongeta': 1050, 'Banaba': 1050, 'Bani': 1050, 'Banuyo': 1050, 'Barako': 1050, 'Bayabas': 1050, 'Betis': 1050, 'Binunga': 1050, 'Dao': 1050, 'Dita': 1050, 'Duhat': 1050, 'Eucalyptus': 1050, 'Guyabano': 1050, 'Hinadyong': 1050, 'Ilang-Ilang': 1050, 'Inyam': 1050, 'Ipil': 1050, 'Kalantas': 1050, 'Kalingag': 1050, 'Kalios': 1050, 'Kamagong': 1050, 'Katmon Bayani': 1050, 'Kayumanis': 1050, 'Kulatingan': 1050, 'Langka': 1050, 'Lansones': 1050, 'Lipote': 1050, 'Madre-Cacao': 1050, 'Mahogany': 1050, 'Malabulak': 1050, 'Malak Malak': 1050, 'Malugai': 1050, 'Mangga': 1050, 'Mulawin': 1050, 'Narra': 1050, 'Palawan Ipil': 1050, 'Palo-Maria': 1050, 'Philippine Oak Ulayan': 1050, 'Puso Puso': 1050, 'Putat': 1050, 'Red Lawaan': 1050, 'Santol': 1050, 'Scramble-Egg': 1050, 'Sintores': 1050, 'Talisay': 1050, 'Tibig': 1050, 'Tui': 1050, 'White Lawaan': 1050, 'Yakal': 1050}

# %%
def plot_image_counts(base_path, output_file="image_counts.png"):
    # Count images in directories
    image_counts = count_images_in_directories(base_path)
    
    # Sort data for better visualization
    sorted_counts = dict(sorted(image_counts.items(), key=lambda item: item[1], reverse=True))
    
    
    # Extract data for the chart
    directories = list(sorted_counts.keys())
    counts = list(sorted_counts.values())
    
    # Plot horizontal bar chart
    plt.figure(figsize=(10, len(directories) * 0.4))  # Adjust height based on the number of directories
    plt.barh(directories, counts, color='skyblue')
    
    # Add labels and title
    plt.xlabel('Number of Classes')
    plt.ylabel('Classes')
    plt.title(f'Number of Classes {len(image_counts)}')
    
    # Display values on bars
    for index, value in enumerate(counts):
        plt.text(value, index, str(value), va='center')
    
    # Save the plot as PNG
    plt.tight_layout()
    plt.savefig(output_file, format="png", dpi=300)
    plt.close()  # Close the plot to free up memory
    
output_path = "images/class_count.png"  
plot_image_counts(DATASET, output_path)
print(f"Plot saved as '{output_path}'")
# Out:
# Plot saved as 'images/class_count.png'
